# %%
# Employee Directory Data Profiling Script
# Dataset: https://open.canada.ca/data/en/dataset/8ec4a9df-b76b-4a67-8f93-cdbc2e040098

import pandas as pd
import numpy as np

# %%
# ----------------------------
# Load dataset
# ----------------------------
file_path = "D:/courses/Data Science/Projects/SQL/employee-directory/data/raw/gedsOpenData.csv"

# Robust CSV load
df = pd.read_csv(
    file_path,
    encoding="latin-1",   # safer than utf-8 for odd chars
    sep=",",              # standard separator
    engine="python",      # python engine handles malformed lines better
    on_bad_lines="skip",  # skip problematic rows instead of crashing
    quotechar='"'         # handle quoted text properly
)

print("✅ Loaded dataset")
print("Shape:", df.shape)
df.head()
print("Columns:", df.columns.tolist())
# Out:
# ✅ Loaded dataset
# Shape: (204608, 44)
# Columns: ['Surname', 'GivenName', 'Initials', 'Prefix (EN)', 'Prefix (FR)', 'Suffix (EN)', 'Suffix (FR)', 'Title (EN)', 'Title (FR)', 'Telephone Number', 'Fax Number', 'TDD Number', 'Secure Telephone Number', 'Secure Fax Number', 'Alternate Telephone Number', 'Email', 'Street Address (EN)', 'Street Address (FR)', 'Country (EN)', 'Country (FR)', 'Province (EN)', 'Province (FR)', 'City (EN)', 'City (FR)', 'Postal Code', 'PO Box (EN)', 'PO Box (FR)', 'Mailstop', 'Building (EN)', 'Building (FR)', 'Floor', 'Room', 'Administrative Assistant', 'Administrative Assistant Telephone Number', 'Executive Assistant', 'Executive Assistant Telephone Number', 'Department Acronym', 'Department Name (EN)', 'Department Name (FR)', 'Organization Acronym', 'Organization Name (EN)', 'Organization Name (FR)', 'Organization Structure (EN)', 'Organization Structure (FR)']

# %%
# ----------------------------
# Basic Overview
# ----------------------------
print("Dataset Shape:", df.shape)
print("\nColumn Names:\n", df.columns.tolist())
print("\nSample Data:\n", df.head(5))
# Out:
# Dataset Shape: (204608, 44)
#
# Column Names:
#  ['Surname', 'GivenName', 'Initials', 'Prefix (EN)', 'Prefix (FR)', 'Suffix (EN)', 'Suffix (FR)', 'Title (EN)', 'Title (FR)', 'Telephone Number', 'Fax Number', 'TDD Number', 'Secure Telephone Number', 'Secure Fax Number', 'Alternate Telephone Number', 'Email', 'Street Address (EN)', 'Street Address (FR)', 'Country (EN)', 'Country (FR)', 'Province (EN)', 'Province (FR)', 'City (EN)', 'City (FR)', 'Postal Code', 'PO Box (EN)', 'PO Box (FR)', 'Mailstop', 'Building (EN)', 'Building (FR)', 'Floor', 'Room', 'Administrative Assistant', 'Administrative Assistant Telephone Number', 'Executive Assistant', 'Executive Assistant Telephone Number', 'Department Acronym', 'Department Name (EN)', 'Department Name (FR)', 'Organization Acronym', 'Organization Name (EN)', 'Organization Name (FR)', 'Organization Structure (EN)', 'Organization Structure (FR)']
#
# Sample Data:
#      Surname  GivenName Initials Prefix (EN) Prefix (FR) Suffix (EN)  \
# 0  Da Silva    Orlando      NaN         NaN         NaN         NaN
# 1   Michaud     Sophie      NaN         NaN         NaN         NaN
# 2  Vermette     Sophie      NaN         NaN         NaN         NaN
# 3    Fraser  Catharine      NaN         NaN         NaN         NaN
# 4  McDonald      Aaron      NaN         NaN         NaN         NaN
#
#   Suffix (FR)                                         Title (EN)  \
# 0         NaN                                Chief Administrator
# 1         NaN  Assistant Director, Organizational Design & Re...
# 2         NaN                       HR Coordinator (Recruitment)
# 3         NaN                                  General Secretary
# 4         NaN                               Office Administrator
#
#                                           Title (FR) Telephone Number  ...  \
# 0                             Administrateur en chef              NaN  ...
# 1  Directrice adjointe, design organisationnel et...              NaN  ...
# 2                  Coordinatrice en RH (Recrutement)              NaN  ...
# 3                                Secrétaire générale     613-990-1807  ...
# 4                               Agent en bureautique     613-991-1808  ...
#
#   Executive Assistant Executive Assistant Telephone Number Department Acronym  \
# 0                 NaN                                  NaN       ATSSC-SCDATA
# 1                 NaN                                  NaN       ATSSC-SCDATA
# 2                 NaN                                  NaN       ATSSC-SCDATA
# 3                 NaN                                  NaN       ATSSC-SCDATA
# 4                 NaN                                  NaN       ATSSC-SCDATA
#
#                                 Department Name (EN)  \
# 0  Administrative Tribunals Support Service of Ca...
# 1  Administrative Tribunals Support Service of Ca...
# 2  Administrative Tribunals Support Service of Ca...
# 3  Administrative Tribunals Support Service of Ca...
# 4  Administrative Tribunals Support Service of Ca...
#
#                                 Department Name (FR) Organization Acronym  \
# 0  Service canadien d'appui aux tribunaux adminis...         ATSSC-SCDATA
# 1  Service canadien d'appui aux tribunaux adminis...           WMOD-GMTDO
# 2  Service canadien d'appui aux tribunaux adminis...           WMOD-GMTDO
# 3  Service canadien d'appui aux tribunaux adminis...              GEN-SEC
# 4  Service canadien d'appui aux tribunaux adminis...              NJC-NJC
#
#                     Organization Name (EN)  \
# 0        Office of the Chief Administrator
# 1      Recruitment & Organizational Design
# 2      Recruitment & Organizational Design
# 3                        General Secretary
# 4  Secretary to the National Joint Council
#
#                         Organization Name (FR)  \
# 0           Bureau de l'administrateur en chef
# 1  Recrutement et conception organisationnelle
# 2  Recrutement et conception organisationnelle
# 3                           Secrétaire général
# 4         Secrétaire du conseil national mixte
#
#                          Organization Structure (EN)  \
# 0  Canada (O=GC,C=CA):Administrative Tribunals Su...
# 1  Canada (O=GC,C=CA):Administrative Tribunals Su...
# 2  Canada (O=GC,C=CA):Administrative Tribunals Su...
# 3  Canada (O=GC,C=CA):Administrative Tribunals Su...
# 4  Canada (O=GC,C=CA):Administrative Tribunals Su...
#
#                          Organization Structure (FR)
# 0  Canada (O=GC,C=CA):Service canadien d'appui au...
# 1  Canada (O=GC,C=CA):Service canadien d'appui au...
# 2  Canada (O=GC,C=CA):Service canadien d'appui au...
# 3  Canada (O=GC,C=CA):Service canadien d'appui au...
# 4  Canada (O=GC,C=CA):Service canadien d'appui au...
#
# [5 rows x 44 columns]

# %%
# ----------------------------
# Column Info
# ----------------------------
print("\nData Types & Nulls:\n")
print(df.info())
print("\nMissing Values:\n", df.isnull().sum())
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Data Types & Nulls:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204608 entries, 0 to 204607
# Data columns (total 44 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Surname                                    204601 non-null  object
#  1   GivenName                                  204600 non-null  object
#  2   Initials                                   6788 non-null    object
#  3   Prefix (EN)                                5031 non-null    object
#  4   Prefix (FR)                                5026 non-null    object
#  5   Suffix (EN)                                1441 non-null    object
#  6   Suffix (FR)                                1438 non-null    object
#  7   Title (EN)                                 194374 non-null  object
#  8   Title (FR)                                 193960 non-null  object
#  9   Telephone Number                           137240 non-null  object
#  10  Fax Number                                 27833 non-null   object
#  11  TDD Number                                 338 non-null     object
#  12  Secure Telephone Number                    179 non-null     object
#  13  Secure Fax Number                          144 non-null     object
#  14  Alternate Telephone Number                 24188 non-null   object
#  15  Email                                      124022 non-null  object
#  16  Street Address (EN)                        181724 non-null  object
#  17  Street Address (FR)                        181536 non-null  object
#  18  Country (EN)                               182120 non-null  object
#  19  Country (FR)                               182119 non-null  object
#  20  Province (EN)                              182171 non-null  object
#  21  Province (FR)                              182171 non-null  object
#  22  City (EN)                                  182107 non-null  object
#  23  City (FR)                                  182107 non-null  object
#  24  Postal Code                                177669 non-null  object
#  25  PO Box (EN)                                35925 non-null   object
#  26  PO Box (FR)                                41314 non-null   object
#  27  Mailstop                                   10255 non-null   object
#  28  Building (EN)                              2845 non-null    object
#  29  Building (FR)                              2845 non-null    object
#  30  Floor                                      2866 non-null    object
#  31  Room                                       2846 non-null    object
#  32  Administrative Assistant                   3768 non-null    object
#  33  Administrative Assistant Telephone Number  2948 non-null    object
#  34  Executive Assistant                        709 non-null     object
#  35  Executive Assistant Telephone Number       586 non-null     object
#  36  Department Acronym                         204608 non-null  object
#  37  Department Name (EN)                       204608 non-null  object
#  38  Department Name (FR)                       204608 non-null  object
#  39  Organization Acronym                       204608 non-null  object
#  40  Organization Name (EN)                     204608 non-null  object
#  41  Organization Name (FR)                     204608 non-null  object
#  42  Organization Structure (EN)                204608 non-null  object
#  43  Organization Structure (FR)                204608 non-null  object
# dtypes: object(44)
# memory usage: 68.7+ MB
# None
#
# Missing Values:
#  Surname                                           7
# GivenName                                         8
# Initials                                     197820
# Prefix (EN)                                  199577
# Prefix (FR)                                  199582
# Suffix (EN)                                  203167
# Suffix (FR)                                  203170
# Title (EN)                                    10234
# Title (FR)                                    10648
# Telephone Number                              67368
# Fax Number                                   176775
# TDD Number                                   204270
# Secure Telephone Number                      204429
# Secure Fax Number                            204464
# Alternate Telephone Number                   180420
# Email                                         80586
# Street Address (EN)                           22884
# Street Address (FR)                           23072
# Country (EN)                                  22488
# Country (FR)                                  22489
# Province (EN)                                 22437
# Province (FR)                                 22437
# City (EN)                                     22501
# City (FR)                                     22501
# Postal Code                                   26939
# PO Box (EN)                                  168683
# PO Box (FR)                                  163294
# Mailstop                                     194353
# Building (EN)                                201763
# Building (FR)                                201763
# Floor                                        201742
# Room                                         201762
# Administrative Assistant                     200840
# Administrative Assistant Telephone Number    201660
# Executive Assistant                          203899
# Executive Assistant Telephone Number         204022
# Department Acronym                                0
# Department Name (EN)                              0
# Department Name (FR)                              0
# Organization Acronym                              0
# Organization Name (EN)                            0
# Organization Name (FR)                            0
# Organization Structure (EN)                       0
# Organization Structure (FR)                       0
# dtype: int64
#
# Duplicate Rows: 61

# %%
# ----------------------------
# Unique values per column
# ----------------------------
for col in df.columns:
    print(f"\nColumn: {col}")
    print(f"Unique Values: {df[col].nunique()}")
    if df[col].nunique() < 20:  # Show categories if small set
        print(df[col].unique())
    print(f"Sample Values: {df[col].dropna().unique()[:5]}")  # Show sample values
# Out:
# Column: Surname
# Unique Values: 65817
# Sample Values: ['Da Silva' 'Michaud' 'Vermette' 'Fraser' 'McDonald']
#
# Column: GivenName
# Unique Values: 30047
# Sample Values: ['Orlando' 'Sophie' 'Catharine' 'Aaron' 'Laura']
#
# Column: Initials
# Unique Values: 778
# Sample Values: ['KL' 'MR' 'E' 'L' 'G']
#
# Column: Prefix (EN)
# Unique Values: 58
# Sample Values: ['Mr.' 'Dr' 'Mx' 'Mrs' 'MS']
#
# Column: Prefix (FR)
# Unique Values: 70
# Sample Values: ['M.' 'Dr' 'Mx' 'Dre' 'Mme']
#
# Column: Suffix (EN)
# Unique Values: 210
# Sample Values: ['CPA, CMA' 'MBA' 'BSc' 'PhD' 'MSc']
#
# Column: Suffix (FR)
# Unique Values: 223
# Sample Values: ['CPA, CMA' 'MBA' 'BSc' 'PhD' 'MSc']
#
# Column: Title (EN)
# Unique Values: 44375
# Sample Values: ['Chief Administrator'
#  'Assistant Director, Organizational Design & Recruitment'
#  'HR Coordinator (Recruitment)' 'General Secretary' 'Office Administrator']
#
# Column: Title (FR)
# Unique Values: 61110
# Sample Values: ['Administrateur en chef'
#  'Directrice adjointe, design organisationnel et recrutement'
#  'Coordinatrice en RH (Recrutement)' 'Secrétaire générale'
#  'Agent en bureautique']
#
# Column: Telephone Number
# Unique Values: 118110
# Sample Values: ['613-990-1807' '613-991-1808' '613-990-1725' '613-793-8211'
#  '343-998-7165']
#
# Column: Fax Number
# Unique Values: 4960
# Sample Values: ['613-990-7071' '613-995-3484' '613-990-9153' '613-773-1061'
#  '613-759-6045']
#
# Column: TDD Number
# Unique Values: 33
# Sample Values: ['506-452-3285' '866-335-3237' '866-633-5323' '800-665-0354'
#  '800-267-2384']
#
# Column: Secure Telephone Number
# Unique Values: 175
# Sample Values: ['506-452-3285' '418-597-3395 x222' '866-549-3745' '888-651-7834 x3067'
#  '888-651-7834 x2925']
#
# Column: Secure Fax Number
# Unique Values: 74
# Sample Values: ['506-452-3285' '613-946-2585' '613-566-4390' '613-991-3441'
#  '905-570-7125']
#
# Column: Alternate Telephone Number
# Unique Values: 23793
# Sample Values: ['613-218-2191' '343-998-9603' '613-853-2870' '343-543-8633'
#  '613-298-6654']
#
# Column: Email
# Unique Values: 123437
# Sample Values: ['fran.young@AGR.GC.CA' 'france.st-laurent@AGR.GC.CA'
#  'georgina.karlis@AGR.GC.CA' 'daniele.tremblay@AGR.GC.CA'
#  'maryanne.mathura@AGR.GC.CA']
#
# Column: Street Address (EN)
# Unique Values: 9219
# Sample Values: ['344 Slater street, 15th Floor, Suite 100'
#  '240 Sparks St, 4th Floor West' '240 Sparks Street, 7th Floor'
#  '240 Sparks St, 4th Floor - West Tower' '344 Slater Street, 15th Floor']
#
# Column: Street Address (FR)
# Unique Values: 10517
# Sample Values: ['344 rue Slater, 15ième étage, Suite 100'
#  '240, rue Sparks, 4e étage ouest' '240, rue sparks, 7e étage'
#  '240, rue Sparks, 4e étage - Tour ouest' '344, rue Slater, 15e étage']
#
# Column: Country (EN)
# Unique Values: 17
# ['Canada' 'Belgium' 'United Kingdom' 'Australia' 'India' 'Türkiye'
#  'Switzerland' 'Mexico' 'Korea, Republic' 'Morocco' 'Germany' nan
#  'United States' 'Italy' 'CANADA' 'CA' 'Ontario' 'France']
# Sample Values: ['Canada' 'Belgium' 'United Kingdom' 'Australia' 'India']
#
# Column: Country (FR)
# Unique Values: 157
# Sample Values: ['Canada' 'Belgique' 'Royaume-Uni' 'Australie' 'Inde']
#
# Column: Province (EN)
# Unique Values: 36
# Sample Values: ['Ontario' 'Quebec' 'British Columbia' 'Nova Scotia' 'Alberta']
#
# Column: Province (FR)
# Unique Values: 59
# Sample Values: ['Ontario' 'Québec' 'Colombie-Britannique' 'Nouvelle-Écosse' 'Alberta']
#
# Column: City (EN)
# Unique Values: 708
# Sample Values: ['Ottawa' 'Toronto' 'Montréal' 'Vancouver' 'Dartmouth']
#
# Column: City (FR)
# Unique Values: 732
# Sample Values: ['Ottawa' 'Toronto' 'Montréal' 'Vancouver' 'Dartmouth']
#
# Column: Postal Code
# Unique Values: 2341
# Sample Values: ['K1A 0B6' 'K1A 0E1' 'K1P 5V2' 'K1A 0L1' 'K1R 7Y3']
#
# Column: PO Box (EN)
# Unique Values: 446
# Sample Values: [' ' 'PO Box 9812, Station T CSC' '1750' 'PO Box 2284, Station M'
#  'PO Box 578']
#
# Column: PO Box (FR)
# Unique Values: 486
# Sample Values: [' ' '1750' 'CP 2284, succursale M' '1060 Stn \\' 'PO Box 1060, Stn C']
#
# Column: Mailstop
# Unique Values: 184
# Sample Values: ['20-4' '25E-18' '20-6' ' ' '8-2']
#
# Column: Building (EN)
# Unique Values: 20
# Sample Values: ['R.H. Coats Building' 'Jean Talon Building' 'Main Building'
#  'Lansing Square' 'Library Square Tower']
#
# Column: Building (FR)
# Unique Values: 20
# Sample Values: ['Immeuble R.-H.-Coats' 'Immeuble Jean-Talon' 'Immeuble Principal'
#  'Immeuble Lansing Square' 'Tour Library Square']
#
# Column: Floor
# Unique Values: 59
# Sample Values: ['2' '7' '2nd' '26' '0']
#
# Column: Room
# Unique Values: 105
# Sample Values: ['210' 'A' 'I' '0' 'G']
#
# Column: Administrative Assistant
# Unique Values: 1512
# Sample Values: ['Laurie Kannegiesser' 'Stephanie LeBlanc' 'Crystal Hawkes'
#  'Suzanne Drouin' 'Ekaterini Retsinas']
#
# Column: Administrative Assistant Telephone Number
# Unique Values: 1286
# Sample Values: ['613-858-2631' '506-866-9578' '506-349-7340' '506-269-3609'
#  '514-283-8700 x8216']
#
# Column: Executive Assistant
# Unique Values: 540
# Sample Values: ['Allison Cormier' 'Kimberly Morin'
#  'EA:Niki Manolikakis SA: Michael Bessette' 'Paula Manzanares'
#  'Céline Grégoire']
#
# Column: Executive Assistant Telephone Number
# Unique Values: 464
# Sample Values: ['506-227-9341' '613-693-0574' '613-402-9229 x_____' '514-283-2488 x5626'
#  '514-283-5483']
#
# Column: Department Acronym
# Unique Values: 141
# Sample Values: ['ATSSC-SCDATA' 'AAFC-AAC' 'APEX-APEX' 'ACOA-APECA' 'APA-APA']
#
# Column: Department Name (EN)
# Unique Values: 141
# Sample Values: ['Administrative Tribunals Support Service of Canada'
#  'Agriculture and Agri-Food Canada'
#  'Association of Professional Executives of the Public Service of Canada'
#  'Atlantic Canada Opportunities Agency' 'Atlantic Pilotage Authority']
#
# Column: Department Name (FR)
# Unique Values: 141
# Sample Values: ["Service canadien d'appui aux tribunaux administratifs"
#  'Agriculture et agroalimentaire Canada'
#  'Association professionnelle des cadres supérieurs de la Fonction publique du Canada'
#  'Agence de promotion économique du Canada atlantique'
#  "Administration de pilotage de l'Atlantique"]
#
# Column: Organization Acronym
# Unique Values: 16358
# Sample Values: ['ATSSC-SCDATA' 'WMOD-GMTDO' 'GEN-SEC' 'NJC-NJC' 'COMP-REMU']
#
# Column: Organization Name (EN)
# Unique Values: 17557
# Sample Values: ['Office of the Chief Administrator' 'Recruitment & Organizational Design'
#  'General Secretary' 'Secretary to the National Joint Council'
#  'Compensation, Benefits & Projects']
#
# Column: Organization Name (FR)
# Unique Values: 18194
# Sample Values: ["Bureau de l'administrateur en chef"
#  'Recrutement et conception organisationnelle' 'Secrétaire général'
#  'Secrétaire du conseil national mixte'
#  'Rémunération, avantages sociaux et projets']
#
# Column: Organization Structure (EN)
# Unique Values: 21031
# Sample Values: ['Canada (O=GC,C=CA):Administrative Tribunals Support Service of Canada (OU=atssc-scdata,O=gc,C=ca):Office of the Chief Administrator (OU=ATSSC-SCDATA,OU=atssc-scdata,O=gc,C=ca)'
#  'Canada (O=GC,C=CA):Administrative Tribunals Support Service of Canada (OU=atssc-scdata,O=gc,C=ca):Corporate Services (OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca):Human Resources, Security and Accommodations (OU=HUM-SER,OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca):Recruitment & Organizational Design (ou=WMOD-GMTDO,OU=HUM-SER,OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca)'
#  'Canada (O=GC,C=CA):Administrative Tribunals Support Service of Canada (OU=atssc-scdata,O=gc,C=ca):National Joint Council (OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca):General Secretary (ou=GEN-SEC,OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca)'
#  'Canada (O=GC,C=CA):Administrative Tribunals Support Service of Canada (OU=atssc-scdata,O=gc,C=ca):National Joint Council (OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca):General Secretary (OU=GEN-SEC,OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca):Secretary to the National Joint Council (ou=NJC-NJC,ou=GEN-SEC,OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca)'
#  'Canada (O=GC,C=CA):Administrative Tribunals Support Service of Canada (OU=atssc-scdata,O=gc,C=ca):Corporate Services (OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca):Human Resources, Security and Accommodations (OU=HUM-SER,OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca):Compensation, Benefits & Projects (ou=COMP-REMU,OU=HUM-SER,OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca)']
#
# Column: Organization Structure (FR)
# Unique Values: 21031
# Sample Values: ["Canada (O=GC,C=CA):Service canadien d'appui aux tribunaux administratifs (OU=atssc-scdata,O=gc,C=ca):Bureau de l'administrateur en chef (OU=ATSSC-SCDATA,OU=atssc-scdata,O=gc,C=ca)"
#  "Canada (O=GC,C=CA):Service canadien d'appui aux tribunaux administratifs (OU=atssc-scdata,O=gc,C=ca):Services de gestion (OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca):Ressources humaines, Sécurité et Aménagements (OU=HUM-SER,OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca):Recrutement et conception organisationnelle (ou=WMOD-GMTDO,OU=HUM-SER,OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca)"
#  "Canada (O=GC,C=CA):Service canadien d'appui aux tribunaux administratifs (OU=atssc-scdata,O=gc,C=ca):Conseil national mixte (OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca):Secrétaire général (ou=GEN-SEC,OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca)"
#  "Canada (O=GC,C=CA):Service canadien d'appui aux tribunaux administratifs (OU=atssc-scdata,O=gc,C=ca):Conseil national mixte (OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca):Secrétaire général (OU=GEN-SEC,OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca):Secrétaire du conseil national mixte (ou=NJC-NJC,ou=GEN-SEC,OU=NJC-CNM,OU=atssc-scdata,O=gc,C=ca)"
#  "Canada (O=GC,C=CA):Service canadien d'appui aux tribunaux administratifs (OU=atssc-scdata,O=gc,C=ca):Services de gestion (OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca):Ressources humaines, Sécurité et Aménagements (OU=HUM-SER,OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca):Rémunération, avantages sociaux et projets (ou=COMP-REMU,OU=HUM-SER,OU=COR-DIR,OU=atssc-scdata,O=gc,C=ca)"]

# %%
# ----------------------------
# Descriptive Statistics
# ----------------------------
print("\nDescriptive Stats (Numeric Columns):\n", df.describe())
print("\nDescriptive Stats (All Columns):\n", df.describe(include='all'))
# Out:
# Descriptive Stats (Numeric Columns):
#         Surname GivenName Initials Prefix (EN) Prefix (FR) Suffix (EN)  \
# count   204601    204600     6788        5031        5026        1441
# unique   65817     30047      778          58          70         210
# top      Smith     David        .          Mr         Mme         PhD
# freq       740      1571      560        1490        1865         583
#
#        Suffix (FR) Title (EN)    Title (FR) Telephone Number  ...  \
# count         1438     194374        193960           137240  ...
# unique         223      44375         61110           118110  ...
# top            PhD    Manager  Gestionnaire     555-555-5555  ...
# freq           577       4085          4004             2688  ...
#
#        Executive Assistant Executive Assistant Telephone Number  \
# count                  709                                  586
# unique                 540                                  464
# top           Deana Beaton                         705-406-2746
# freq                    13                                   14
#
#        Department Acronym                      Department Name (EN)  \
# count              204608                                    204608
# unique                141                                       141
# top             ESDC-EDSC  Employment and Social Development Canada
# freq                15285                                     15285
#
#                          Department Name (FR) Organization Acronym  \
# count                                  204608               204608
# unique                                    141                16358
# top     Emploi et Développement social Canada              DGO-BDG
# freq                                    15285                 1281
#
#                         Organization Name (EN)  \
# count                                   204608
# unique                                   17557
# top     Industrial Research Assistance Program
# freq                                       780
#
#                               Organization Name (FR)  \
# count                                         204608
# unique                                         18194
# top     Programme d'aide à la recherche industrielle
# freq                                             780
#
#                               Organization Structure (EN)  \
# count                                              204608
# unique                                              21031
# top     Canada (O=GC,C=CA):National Research Council C...
# freq                                                  780
#
#                               Organization Structure (FR)
# count                                              204608
# unique                                              21031
# top     Canada (O=GC,C=CA):Conseil national de recherc...
# freq                                                  780
#
# [4 rows x 44 columns]
#
# Descriptive Stats (All Columns):
#         Surname GivenName Initials Prefix (EN) Prefix (FR) Suffix (EN)  \
# count   204601    204600     6788        5031        5026        1441
# unique   65817     30047      778          58          70         210
# top      Smith     David        .          Mr         Mme         PhD
# freq       740      1571      560        1490        1865         583
#
#        Suffix (FR) Title (EN)    Title (FR) Telephone Number  ...  \
# count         1438     194374        193960           137240  ...
# unique         223      44375         61110           118110  ...
# top            PhD    Manager  Gestionnaire     555-555-5555  ...
# freq           577       4085          4004             2688  ...
#
#        Executive Assistant Executive Assistant Telephone Number  \
# count                  709                                  586
# unique                 540                                  464
# top           Deana Beaton                         705-406-2746
# freq                    13                                   14
#
#        Department Acronym                      Department Name (EN)  \
# count              204608                                    204608
# unique                141                                       141
# top             ESDC-EDSC  Employment and Social Development Canada
# freq                15285                                     15285
#
#                          Department Name (FR) Organization Acronym  \
# count                                  204608               204608
# unique                                    141                16358
# top     Emploi et Développement social Canada              DGO-BDG
# freq                                    15285                 1281
#
#                         Organization Name (EN)  \
# count                                   204608
# unique                                   17557
# top     Industrial Research Assistance Program
# freq                                       780
#
#                               Organization Name (FR)  \
# count                                         204608
# unique                                         18194
# top     Programme d'aide à la recherche industrielle
# freq                                             780
#
#                               Organization Structure (EN)  \
# count                                              204608
# unique                                              21031
# top     Canada (O=GC,C=CA):National Research Council C...
# freq                                                  780
#
#                               Organization Structure (FR)
# count                                              204608
# unique                                              21031
# top     Canada (O=GC,C=CA):Conseil national de recherc...
# freq                                                  780
#
# [4 rows x 44 columns]

# %%
# ----------------------------
# Text Columns Profiling
# ----------------------------
text_cols = df.select_dtypes(include=["object"]).columns
for col in text_cols:
    print(f"\nTop 5 most frequent values in {col}:")
    print(df[col].value_counts().head(5))
    print(f"\nLength stats for {col}:")
# Out:
# Top 5 most frequent values in Surname:
# Surname
# Smith       740
# Roy         501
# Tremblay    495
# Lee         459
# Gauthier    445
# Name: count, dtype: int64
#
# Length stats for Surname:
#
# Top 5 most frequent values in GivenName:
# GivenName
# David       1571
# Jennifer    1476
# Julie       1449
# Michael     1432
# Sarah       1242
# Name: count, dtype: int64
#
# Length stats for GivenName:
#
# Top 5 most frequent values in Initials:
# Initials
#  .    560
# A     495
# J     488
# M     467
# L     316
# Name: count, dtype: int64
#
# Length stats for Initials:
#
# Top 5 most frequent values in Prefix (EN):
# Prefix (EN)
# Mr      1490
# Dr       993
# Ms       970
# Mrs      920
# Miss     153
# Name: count, dtype: int64
#
# Length stats for Prefix (EN):
#
# Top 5 most frequent values in Prefix (FR):
# Prefix (FR)
# Mme     1865
# M.      1585
# Dr       862
# Mlle     161
# Dre      127
# Name: count, dtype: int64
#
# Length stats for Prefix (FR):
#
# Top 5 most frequent values in Suffix (EN):
# Suffix (EN)
# PhD           583
# MSc           170
# BSc           115
# (she, her)    101
# DVM            91
# Name: count, dtype: int64
#
# Length stats for Suffix (EN):
#
# Top 5 most frequent values in Suffix (FR):
# Suffix (FR)
# PhD           577
# MSc           171
# BSc           115
# (elle, la)    101
# DMV            90
# Name: count, dtype: int64
#
# Length stats for Suffix (FR):
#
# Top 5 most frequent values in Title (EN):
# Title (EN)
# Manager                     4085
# Policy Analyst              3076
# Student                     2979
# Administrative Assistant    2448
# Counsel                     2315
# Name: count, dtype: int64
#
# Length stats for Title (EN):
#
# Top 5 most frequent values in Title (FR):
# Title (FR)
# Gestionnaire               4004
# Not Specified              1886
# Analyste                   1557
# Analyste des politiques    1449
# Chef d'équipe              1257
# Name: count, dtype: int64
#
# Length stats for Title (FR):
#
# Top 5 most frequent values in Telephone Number:
# Telephone Number
# 555-555-5555    2688
# 000-000-0000     354
# 902-564-3660     287
# 613-995-3708     217
# 613-000-0000     182
# Name: count, dtype: int64
#
# Length stats for Telephone Number:
#
# Top 5 most frequent values in Fax Number:
# Fax Number
# 613-995-5086    918
# 403-382-3156    323
# 613-941-1436    239
# 604-775-7149    169
# 819-564-5507    159
# Name: count, dtype: int64
#
# Length stats for Fax Number:
#
# Top 5 most frequent values in TDD Number:
# TDD Number
# E               158
# 877-303-3388    109
# 800-267-2384     24
# 866-335-3237     10
# 819-953-7287      3
# Name: count, dtype: int64
#
# Length stats for TDD Number:
#
# Top 5 most frequent values in Secure Telephone Number:
# Secure Telephone Number
# 613-000-0000          3
# 709-772-4896          2
# 01                    2
# 888-651-7834 x3067    1
# 506-452-3285          1
# Name: count, dtype: int64
#
# Length stats for Secure Telephone Number:
#
# Top 5 most frequent values in Secure Fax Number:
# Secure Fax Number
# 613-946-2585           35
# 613-744-9631           12
# 613-952-5824            5
# ___-___-____ x_____     4
# 343-944-1606            3
# Name: count, dtype: int64
#
# Length stats for Secure Fax Number:
#
# Top 5 most frequent values in Alternate Telephone Number:
# Alternate Telephone Number
# 800-465-6890    92
# 867-667-8100    39
# 555-555-5555    28
# 800-567-9604    22
# 000-000-0000    19
# Name: count, dtype: int64
#
# Length stats for Alternate Telephone Number:
#
# Top 5 most frequent values in Email:
# Email
# jennifer.black@hc-sc.gc.ca       6
# myriam.salem@hc-sc.gc.ca         5
# larbi.elbilali@hc-sc.gc.ca       4
# jaspaul.hothi@hc-sc.gc.ca        4
# daniel.baxter@phac-aspc.gc.ca    4
# Name: count, dtype: int64
#
# Length stats for Email:
#
# Top 5 most frequent values in Street Address (EN):
# Street Address (EN)
# 140 Promenade du Portage    4580
# 235 Queen St                4078
# 330 Sparks Street           3097
# 351 Saint-Joseph Blvd       2817
# 125 Sussex Drive            2513
# Name: count, dtype: int64
#
# Length stats for Street Address (EN):
#
# Top 5 most frequent values in Street Address (FR):
# Street Address (FR)
# 140 Promenade du Portage    4580
# 235 rue Queen               4098
# 330 Rue Sparks              3097
# 351, boul. Saint-Joseph     2817
# 125, promenade Sussex       2485
# Name: count, dtype: int64
#
# Length stats for Street Address (FR):
#
# Top 5 most frequent values in Country (EN):
# Country (EN)
# Canada           181866
# Ontario             158
# CA                   51
# Belgium              16
# United States        12
# Name: count, dtype: int64
#
# Length stats for Country (EN):
#
# Top 5 most frequent values in Country (FR):
# Country (FR)
# Canada        181865
# CA                51
# K1P 6L5           17
# Belgique          16
# États-Unis        12
# Name: count, dtype: int64
#
# Length stats for Country (FR):
#
# Top 5 most frequent values in Province (EN):
# Province (EN)
# Ontario             97855
# Quebec              43942
# British Columbia     9566
# Alberta              7222
# Nova Scotia          5245
# Name: count, dtype: int64
#
# Length stats for Province (EN):
#
# Top 5 most frequent values in Province (FR):
# Province (FR)
# Ontario                 97856
# Québec                  43959
# Colombie-Britannique     8619
# Alberta                  7222
# Nouvelle-Écosse          5232
# Name: count, dtype: int64
#
# Length stats for Province (FR):
#
# Top 5 most frequent values in City (EN):
# City (EN)
# Ottawa       83461
# Gatineau     29683
# Montréal      5680
# Toronto       5175
# Vancouver     4635
# Name: count, dtype: int64
#
# Length stats for City (EN):
#
# Top 5 most frequent values in City (FR):
# City (FR)
# Ottawa       83453
# Gatineau     29683
# Montréal      6316
# Toronto       5174
# Vancouver     4634
# Name: count, dtype: int64
#
# Length stats for City (FR):
#
# Top 5 most frequent values in Postal Code:
# Postal Code
# K1A 0L5    8546
# K1A 1L1    5256
# K1A 0H4    4983
# K1A 0J9    4726
# K1A 0H5    4311
# Name: count, dtype: int64
#
# Length stats for Postal Code:
#
# Top 5 most frequent values in PO Box (EN):
# PO Box (EN)
#                               26153
# PO Box 9808, Station T CSC     3158
# PO Box 1046, Station B          856
# PO Box 1610, Station B          565
# PO Box 5667                     486
# Name: count, dtype: int64
#
# Length stats for PO Box (EN):
#
# Top 5 most frequent values in PO Box (FR):
# PO Box (FR)
#                              35862
# CP 9808, succursale T CSC     2566
# CP 1006                        204
# C.P 160                        153
# CP 1000                        145
# Name: count, dtype: int64
#
# Length stats for PO Box (FR):
#
# Top 5 most frequent values in Mailstop:
# Mailstop
#          5420
# 6-6       196
# 6604C     168
# 6604E     156
# 1902D     131
# Name: count, dtype: int64
#
# Length stats for Mailstop:
#
# Top 5 most frequent values in Building (EN):
# Building (EN)
# Main Building                  759
# Jean Talon Building            681
# R.H. Coats Building            629
# Eastern Regional Office        185
# Civic Administration Centre    131
# Name: count, dtype: int64
#
# Length stats for Building (EN):
#
# Top 5 most frequent values in Building (FR):
# Building (FR)
# Immeuble Principal                 759
# Immeuble Jean-Talon                681
# Immeuble R.-H.-Coats               629
# Bureau régional de l'est           185
# Centre d'administration civique    131
# Name: count, dtype: int64
#
# Length stats for Building (FR):
#
# Top 5 most frequent values in Floor:
# Floor
# 0    760
# 1    277
# 2    222
# 7    192
# 4    155
# Name: count, dtype: int64
#
# Length stats for Floor:
#
# Top 5 most frequent values in Room:
# Room
# 0      1908
# A        46
# B        31
# A-1      31
# P        28
# Name: count, dtype: int64
#
# Length stats for Room:
#
# Top 5 most frequent values in Administrative Assistant:
# Administrative Assistant
# Stephanie Lauzon            58
# Suzanne Savoie              50
# Malorie Parent Cousineau    49
# Julie Fullerton             41
# Judy Cormier                33
# Name: count, dtype: int64
#
# Length stats for Administrative Assistant:
#
# Top 5 most frequent values in Administrative Assistant Telephone Number:
# Administrative Assistant Telephone Number
# 873-455-7599    49
# 506-531-5403    41
# 506-531-8294    31
# 418-953-7833    30
# 343-597-5501    29
# Name: count, dtype: int64
#
# Length stats for Administrative Assistant Telephone Number:
#
# Top 5 most frequent values in Executive Assistant:
# Executive Assistant
# Deana Beaton       13
# Emma L Nabb        13
# Chloe Panko        12
# Emma Nabb          11
# Emily Henderson    10
# Name: count, dtype: int64
#
# Length stats for Executive Assistant:
#
# Top 5 most frequent values in Executive Assistant Telephone Number:
# Executive Assistant Telephone Number
# 705-406-2746    14
# 613-000-0000     6
# 343-552-9173     6
# 873-416-0966     6
# 438-458-5975     5
# Name: count, dtype: int64
#
# Length stats for Executive Assistant Telephone Number:
#
# Top 5 most frequent values in Department Acronym:
# Department Acronym
# ESDC-EDSC    15285
# DFO-MPO      12204
# HC-SC        10923
# CRA-ARC      10092
# PSPC-SPAC     9334
# Name: count, dtype: int64
#
# Length stats for Department Acronym:
#
# Top 5 most frequent values in Department Name (EN):
# Department Name (EN)
# Employment and Social Development Canada    15285
# Fisheries and Oceans Canada                 12204
# Health Canada                               10923
# CANADA REVENUE AGENCY                       10092
# Public Services and Procurement Canada       9334
# Name: count, dtype: int64
#
# Length stats for Department Name (EN):
#
# Top 5 most frequent values in Department Name (FR):
# Department Name (FR)
# Emploi et Développement social Canada           15285
# Pêches et Océans Canada                         12204
# Santé Canada                                    10923
# AGENCE DU REVENU DU CANADA                      10092
# Services publics et Approvisionnement Canada     9334
# Name: count, dtype: int64
#
# Length stats for Department Name (FR):
#
# Top 5 most frequent values in Organization Acronym:
# Organization Acronym
# DGO-BDG      1281
# IRAP-PARI     780
# DO-BD         720
# AERO-AERO     622
# DIR-BUR       607
# Name: count, dtype: int64
#
# Length stats for Organization Acronym:
#
# Top 5 most frequent values in Organization Name (EN):
# Organization Name (EN)
# Industrial Research Assistance Program    780
# DIRECTOR'S OFFICE                         743
# DIRECTOR GENERAL'S OFFICE                 629
# Construction                              625
# Aerospace                                 622
# Name: count, dtype: int64
#
# Length stats for Organization Name (EN):
#
# Top 5 most frequent values in Organization Name (FR):
# Organization Name (FR)
# Programme d'aide à la recherche industrielle                      780
# Construction                                                      625
# Aérospatiale                                                      622
# BUREAU DU DIRECTEUR                                               559
# Direction générale des services de connectivité et de sécurité    552
# Name: count, dtype: int64
#
# Length stats for Organization Name (FR):
#
# Top 5 most frequent values in Organization Structure (EN):
# Organization Structure (EN)
# Canada (O=GC,C=CA):National Research Council Canada (OU=nrc-cnrc,O=gc,C=ca):Industrial Research Assistance Program (OU=IRAP-PARI,OU=nrc-cnrc,O=gc,C=ca)                                                  780
# Canada (O=GC,C=CA):National Research Council Canada (OU=NRC-CNRC,O=gc,C=ca):Transportation and Manufacturing (OU=TM-TF,OU=NRC-CNRC,O=gc,C=ca):Aerospace (ou=AERO-AERO,ou=TM-TF,ou=NRC-CNRC,o=gc,c=ca)    622
# Canada (O=GC,C=CA):National Research Council Canada (OU=nrc-cnrc,O=gc,C=ca):Engineering (OU=ENG-GEN,OU=nrc-cnrc,O=gc,C=ca):Construction (ou=CONST-CONST,OU=ENG-GEN,OU=nrc-cnrc,O=gc,C=ca)                602
# Canada (O=GC,C=CA):Shared Services Canada (OU=ssc-spc,O=gc,C=ca):Connectivity and Security Services Branch (ou=CSSB-DGSCS,OU=ssc-spc,O=gc,C=ca)                                                          552
# Canada (O=GC,C=CA):National Research Council Canada (OU=NRC-CNRC,O=gc,C=ca):Life Sciences (OU=LS-SV,OU=NRC-CNRC,O=gc,C=ca):Human Health Therapeutics (ou=HHT-TSH,ou=LS-SV,ou=NRC-CNRC,o=gc,c=ca)         473
# Name: count, dtype: int64
#
# Length stats for Organization Structure (EN):
#
# Top 5 most frequent values in Organization Structure (FR):
# Organization Structure (FR)
# Canada (O=GC,C=CA):Conseil national de recherches Canada (OU=nrc-cnrc,O=gc,C=ca):Programme d'aide à la recherche industrielle (OU=IRAP-PARI,OU=nrc-cnrc,O=gc,C=ca)                                                  780
# Canada (O=GC,C=CA):Conseil national de recherches Canada (OU=NRC-CNRC,O=gc,C=ca):Transports et fabrication (OU=TM-TF,OU=NRC-CNRC,O=gc,C=ca):Aérospatiale (ou=AERO-AERO,ou=TM-TF,ou=NRC-CNRC,o=gc,c=ca)              622
# Canada (O=GC,C=CA):Conseil national de recherches Canada (OU=nrc-cnrc,O=gc,C=ca):Génie (OU=ENG-GEN,OU=nrc-cnrc,O=gc,C=ca):Construction (ou=CONST-CONST,OU=ENG-GEN,OU=nrc-cnrc,O=gc,C=ca)                            602
# Canada (O=GC,C=CA):Services partagés Canada (OU=ssc-spc,O=gc,C=ca):Direction générale des services de connectivité et de sécurité (ou=CSSB-DGSCS,OU=ssc-spc,O=gc,C=ca)                                              552
# Canada (O=GC,C=CA):Conseil national de recherches Canada (OU=NRC-CNRC,O=gc,C=ca):Sciences de la vie (OU=LS-SV,OU=NRC-CNRC,O=gc,C=ca):Thérapeutiques en santé humaine (ou=HHT-TSH,ou=LS-SV,ou=NRC-CNRC,o=gc,c=ca)    473
# Name: count, dtype: int64
#
# Length stats for Organization Structure (FR):

# %%
# ----------------------------
# Data Cleaning Checks
# ----------------------------
# Trim spaces in string columns
df[text_cols] = df[text_cols].apply(lambda x: x.str.strip())

# %%
# Check duplicates
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 61

# %%
# Check first few rows
df.head()

# Quick info
df.info()

# Missing values check
df.isnull().sum().sort_values(ascending=False)

# Unique values per column
df.nunique().sort_values()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204608 entries, 0 to 204607
# Data columns (total 44 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Surname                                    204601 non-null  object
#  1   GivenName                                  204600 non-null  object
#  2   Initials                                   6788 non-null    object
#  3   Prefix (EN)                                5031 non-null    object
#  4   Prefix (FR)                                5026 non-null    object
#  5   Suffix (EN)                                1441 non-null    object
#  6   Suffix (FR)                                1438 non-null    object
#  7   Title (EN)                                 194374 non-null  object
#  8   Title (FR)                                 193960 non-null  object
#  9   Telephone Number                           137240 non-null  object
#  10  Fax Number                                 27833 non-null   object
#  11  TDD Number                                 338 non-null     object
#  12  Secure Telephone Number                    179 non-null     object
#  13  Secure Fax Number                          144 non-null     object
#  14  Alternate Telephone Number                 24188 non-null   object
#  15  Email                                      124022 non-null  object
#  16  Street Address (EN)                        181724 non-null  object
#  17  Street Address (FR)                        181536 non-null  object
#  18  Country (EN)                               182120 non-null  object
#  19  Country (FR)                               182119 non-null  object
#  20  Province (EN)                              182171 non-null  object
#  21  Province (FR)                              182171 non-null  object
#  22  City (EN)                                  182107 non-null  object
#  23  City (FR)                                  182107 non-null  object
#  24  Postal Code                                177669 non-null  object
#  25  PO Box (EN)                                35925 non-null   object
#  26  PO Box (FR)                                41314 non-null   object
#  27  Mailstop                                   10255 non-null   object
#  28  Building (EN)                              2845 non-null    object
#  29  Building (FR)                              2845 non-null    object
#  30  Floor                                      2866 non-null    object
#  31  Room                                       2846 non-null    object
#  32  Administrative Assistant                   3768 non-null    object
#  33  Administrative Assistant Telephone Number  2948 non-null    object
#  34  Executive Assistant                        709 non-null     object
#  35  Executive Assistant Telephone Number       586 non-null     object
#  36  Department Acronym                         204608 non-null  object
#  37  Department Name (EN)                       204608 non-null  object
#  38  Department Name (FR)                       204608 non-null  object
#  39  Organization Acronym                       204608 non-null  object
#  40  Organization Name (EN)                     204608 non-null  object
#  41  Organization Name (FR)                     204608 non-null  object
#  42  Organization Structure (EN)                204608 non-null  object
#  43  Organization Structure (FR)                204608 non-null  object
# dtypes: object(44)
# memory usage: 68.7+ MB
# Country (EN)                                     17
# Building (FR)                                    20
# Building (EN)                                    20
# TDD Number                                       33
# Province (EN)                                    35
# Prefix (EN)                                      58
# Floor                                            59
# Province (FR)                                    59
# Prefix (FR)                                      70
# Secure Fax Number                                74
# Room                                            105
# Department Name (EN)                            141
# Department Name (FR)                            141
# Department Acronym                              141
# Country (FR)                                    157
# Secure Telephone Number                         175
# Mailstop                                        184
# Suffix (EN)                                     210
# Suffix (FR)                                     223
# PO Box (EN)                                     446
# Executive Assistant Telephone Number            464
# PO Box (FR)                                     486
# Executive Assistant                             538
# City (EN)                                       703
# City (FR)                                       726
# Initials                                        775
# Administrative Assistant Telephone Number      1286
# Administrative Assistant                       1512
# Postal Code                                    2340
# Fax Number                                     4960
# Street Address (EN)                            9193
# Street Address (FR)                           10496
# Organization Acronym                          16358
# Organization Name (EN)                        17537
# Organization Name (FR)                        18189
# Organization Structure (EN)                   21031
# Organization Structure (FR)                   21031
# Alternate Telephone Number                    23793
# GivenName                                     29944
# Title (EN)                                    43929
# Title (FR)                                    60236
# Surname                                       65794
# Telephone Number                             118110
# Email                                        123437
# dtype: int64

# %%
# Normalize names (remove spaces, title case)
df['Surname'] = df['Surname'].str.strip().str.title()
df['GivenName'] = df['GivenName'].str.strip().str.title()

# Combine to full name
df['Full_Name'] = df['GivenName'] + " " + df['Surname']

# Standardize emails (lowercase, strip spaces)
df['Email'] = df['Email'].str.strip().str.lower()

# %%
# Check phone number formats
df['Telephone Number'] = df['Telephone Number'].str.replace(r'\D', '', regex=True)

# Count how many missing emails
df['Email'].isna().sum()

# Flag invalid emails
df['Valid_Email'] = df['Email'].str.contains(r'^[\w\.-]+@[\w\.-]+\.\w+$', regex=True)

# %%
org_cols = ['Department Acronym', 'Department Name (EN)', 'Organization Acronym', 'Organization Name (EN)', 'Organization Structure (EN)']
df[org_cols].drop_duplicates().head(10)
# Out:
#    Department Acronym                               Department Name (EN)  \
# 0        ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 1        ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 3        ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 4        ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 9        ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 11       ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 15       ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 21       ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 30       ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
# 37       ATSSC-SCDATA  Administrative Tribunals Support Service of Ca...
#
#    Organization Acronym                    Organization Name (EN)  \
# 0          ATSSC-SCDATA         Office of the Chief Administrator
# 1            WMOD-GMTDO       Recruitment & Organizational Design
# 3               GEN-SEC                         General Secretary
# 4               NJC-NJC   Secretary to the National Joint Council
# 9             COMP-REMU         Compensation, Benefits & Projects
# 11              ACC-OPE                     Accounting Operations
# 15              RES-GES                      Resources Management
# 21              COR-SER                  Corporate Legal Services
# 30               WP-GMT                      Workplace Management
# 37            ODCA-BACA  Office of the Deputy Chief Administrator
#
#                           Organization Structure (EN)
# 0   Canada (O=GC,C=CA):Administrative Tribunals Su...
# 1   Canada (O=GC,C=CA):Administrative Tribunals Su...
# 3   Canada (O=GC,C=CA):Administrative Tribunals Su...
# 4   Canada (O=GC,C=CA):Administrative Tribunals Su...
# 9   Canada (O=GC,C=CA):Administrative Tribunals Su...
# 11  Canada (O=GC,C=CA):Administrative Tribunals Su...
# 15  Canada (O=GC,C=CA):Administrative Tribunals Su...
# 21  Canada (O=GC,C=CA):Administrative Tribunals Su...
# 30  Canada (O=GC,C=CA):Administrative Tribunals Su...
# 37  Canada (O=GC,C=CA):Administrative Tribunals Su...

# %%
# Create a unified address field (English only for now)
df['Full_Address'] = (
    df['Street Address (EN)'].fillna('') + ", " +
    df['City (EN)'].fillna('') + ", " +
    df['Province (EN)'].fillna('') + ", " +
    df['Country (EN)'].fillna('') + " " +
    df['Postal Code'].fillna('')
).str.strip(", ")

# %%
# Drop duplicates by Email
df_unique = df.drop_duplicates(subset=['Email'], keep='first')

# Or by Full_Name + Department
df_unique = df.drop_duplicates(subset=['Full_Name', 'Department Name (EN)'], keep='first')

# %%
# Export cleaned dataset
df.to_csv("contacts_cleaned.csv", index=False)
